# %% [markdown]
# # Imports

# %%
import sys
import os

from pyspark import SparkContext, SparkConf
from pyspark.sql.session import SparkSession

# %%
app_name="Case Study 1"

conf = SparkConf().setAppName(app_name)
sc = SparkContext(conf = conf)
spark = SparkSession(sc)

# %%
sc.applicationId
# Out:
# 'local-1573654541439'

# %%
log4jLogger = sc._jvm.org.apache.log4j
LOGGER = log4jLogger.LogManager.getLogger(__name__)
LOGGER.info("pyspark script logger initialized")

# %% [markdown]
# # Load data into Spark DataFrame

# %%
def get_hdfs_filepath(file_name, on_cloud=True):
    # path to folder containing this code
    
    prefix = '/data/spark/6_cs1_dataset/'
    if on_cloud:
        bucket  = os.environ['BUCKET']
        file_path = bucket + prefix + file_name
    else:
        file_path = '/Users/val' + prefix + file_name

    return file_path

# %%
AISLES = get_hdfs_filepath('aisles.csv')
DEPARTMENTS = get_hdfs_filepath('departments.csv')
ORDER_PRODUCTS_PRIOR = get_hdfs_filepath('order_products__prior.csv')
ORDER_PRODUCTS_TRAIN = get_hdfs_filepath('order_products__train.csv')
ORDERS = get_hdfs_filepath('orders.csv')
PRODUCTS = get_hdfs_filepath('products.csv')

# %%
# !file '/Users/val/work/data/spark/6_cs1_dataset/aisles.csv'
# Out:
# /Users/val/work/data/spark/6_cs1_dataset/aisles.csv: cannot open `/Users/val/work/data/spark/6_cs1_dataset/aisles.csv' (No such file or directory)

# %%
df_aisles = spark.read.csv(AISLES, multiLine=True, header="true",encoding='ASCII', escape= "\"",inferSchema =True)
df_departments = spark.read.csv(DEPARTMENTS, multiLine=True, header="true",encoding='ASCII', escape= "\"",inferSchema =True)
df_order_products_prior = spark.read.csv(ORDER_PRODUCTS_PRIOR, multiLine=True, header="true",encoding='ASCII', escape= "\"",inferSchema =True)
df_order_products_train = spark.read.csv(ORDER_PRODUCTS_TRAIN, multiLine=True, header="true",encoding='ASCII', escape= "\"",inferSchema =True)
df_orders = spark.read.csv(ORDERS, multiLine=True, header="true",encoding='ASCII', escape= "\"",inferSchema =True)
df_products = spark.read.csv(PRODUCTS, multiLine=True, header="true",encoding='ASCII', escape= "\"",inferSchema =True)

# %% [markdown]
# # Merge all the data frames based on the common key and create a single DataFrame

# %% [markdown]
# ### Using dataframe joins

# %%
# 1: orders + order_products
orders_train_df = df_orders.join(df_order_products_train, "order_id")
orders_prior_df = df_orders.join(df_order_products_prior, "order_id")

# 2: products + aisles + departments
prod_isles_dep_df = df_departments.join(df_products, "department_id").join(df_aisles, "aisle_id")

# 3: orders + order_products + products + aisles + departments
orders_all_train = prod_isles_dep_df.join(orders_train_df, "product_id")
orders_all_prior = prod_isles_dep_df.join(orders_prior_df, "product_id")

# 4: train + prior
orders_all_df = orders_all_train.union(orders_all_prior)

# %%
import time
start_time = time.time()

orders_all_df.limit(20).toPandas()

#print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#     product_id  aisle_id  department_id department product_name         aisle  \
# 0          148        24              4    produce   Nectarines  fresh fruits
# 1          148        24              4    produce   Nectarines  fresh fruits
# 2          148        24              4    produce   Nectarines  fresh fruits
# 3          148        24              4    produce   Nectarines  fresh fruits
# 4          148        24              4    produce   Nectarines  fresh fruits
# 5          148        24              4    produce   Nectarines  fresh fruits
# 6          148        24              4    produce   Nectarines  fresh fruits
# 7          148        24              4    produce   Nectarines  fresh fruits
# 8          148        24              4    produce   Nectarines  fresh fruits
# 9          148        24              4    produce   Nectarines  fresh fruits
# 10         148        24              4    produce   Nectarines  fresh fruits
# 11         148        24              4    produce   Nectarines  fresh fruits
# 12         148        24              4    produce   Nectarines  fresh fruits
# 13         148        24              4    produce   Nectarines  fresh fruits
# 14         148        24              4    produce   Nectarines  fresh fruits
# 15         148        24              4    produce   Nectarines  fresh fruits
# 16         148        24              4    produce   Nectarines  fresh fruits
# 17         148        24              4    produce   Nectarines  fresh fruits
# 18         148        24              4    produce   Nectarines  fresh fruits
# 19         148        24              4    produce   Nectarines  fresh fruits
#
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     704303    90705    train            22          1                 14
# 1     732117   125220    train             6          1                 16
# 2      36580   112691    train            41          0                 14
# 3    1669930    31331    train            14          5                 21
# 4    1524400    11241    train             4          2                 11
# 5     292177   201763    train            37          0                 13
# 6     842159    74316    train             4          0                 19
# 7    3363512    80075    train            42          1                 15
# 8     129966   170386    train             4          6                 16
# 9    1337576    37289    train            20          3                 13
# 10   2449193    96749    train             7          2                 16
# 11   1149422    84150    train             7          5                 11
# 12   3059999   204623    train             4          6                 15
# 13   3367448    67309    train            16          3                 13
# 14    604121   113128    train             6          0                 10
# 15    982020    55067    train             5          5                 12
# 16   2996268   167237    train             8          1                 23
# 17   2240205    62381    train             4          1                 21
# 18   2540228    38686    train            29          1                 14
# 19   1226580   190228    train             4          0                 11
#
#     days_since_prior_order  add_to_cart_order  reordered
# 0                     25.0                  9          1
# 1                     21.0                 24          0
# 2                     19.0                 24          1
# 3                     21.0                  3          1
# 4                     30.0                 10          0
# 5                      8.0                  2          1
# 6                      7.0                 15          1
# 7                      4.0                  5          1
# 8                      8.0                 11          1
# 9                     12.0                  5          1
# 10                    30.0                  3          0
# 11                    30.0                  4          0
# 12                    30.0                  6          0
# 13                    28.0                  7          1
# 14                    28.0                  4          1
# 15                    30.0                  8          0
# 16                     4.0                 13          0
# 17                    12.0                 14          1
# 18                    15.0                 29          1
# 19                    30.0                  1          0

# %% [markdown]
# ### Using spark.sql querries

# %%
df_aisles.createOrReplaceTempView('Aisles')
df_departments.createOrReplaceTempView('Departments')
df_order_products_prior.createOrReplaceTempView('Order_products_prior')
df_order_products_train.createOrReplaceTempView('Order_products_train')
df_orders.createOrReplaceTempView('Orders')
df_products.createOrReplaceTempView('Products')

# %%
querry = """
Select
  m1.order_id,
  m1.user_id,
  m1.eval_set,
  m1.order_number,
  m1.order_dow,
  m1.order_hour_of_day,
  m1.days_since_prior_order,
  m1.product_id,
  m1.add_to_cart_order,
  m1.reordered,
  m2.product_name,
  m2.aisle_id,
  m2.aisle,
  m2.department_id,
  m2.department 
From
  (
    Select
      o.order_id,
      o.user_id,
      o.eval_set,
      o.order_number,
      o.order_dow,
      o.order_hour_of_day,
      o.days_since_prior_order,
      op.product_id,
      op.add_to_cart_order,
      op.reordered 
    From
      Orders o 
      INNER JOIN
        (
          SELECT
            * 
          FROM
            Order_products_train 
          UNION ALL
          SELECT
            * 
          FROM
            Order_products_prior
        )
        op 
        on o.order_id = op.order_id 
  )
  m1 
  INNER JOIN
    (
      Select
        p.product_id,
        p.product_name,
        p.aisle_id,
        a.aisle,
        p.department_id,
        d.department 
      From
        Departments d 
        INNER JOIN
          Products p 
          on d.department_id = p.department_id 
        INNER JOIN
          Aisles a 
          on p.aisle_id = a.aisle_id 
    )
    m2 
    on m1.product_id = m2.product_id
"""

# %%
orders_all_df = spark.sql(querry)
orders_all_df.createOrReplaceTempView('Orders_all')

# %%
import time
start_time = time.time()

orders_all_df.limit(20).toPandas()

#print("--- %s seconds ---" % (time.time() - start_time))
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0     133160    47136    prior             3          0                 18
# 1     210175    12428    prior            14          5                 15
# 2     295286    63587    prior             1          3                 22
# 3     407324   158452    prior            11          2                  9
# 4     544414    82360    prior             3          6                 20
# 5     602118   157841    prior            12          4                 14
# 6     716590     8196    prior             1          4                 17
# 7     730383    30910    prior             3          5                 21
# 8     734099   122073    prior             9          6                  7
# 9    1074455   145986    prior             6          3                 16
# 10   1300552    71822    prior            43          1                  8
# 11   1382485    86164    prior             5          3                 13
# 12   1487488   147636    prior            21          1                 21
# 13   1503403     4090    prior            43          2                 15
# 14   1932914   115867    prior            21          5                 11
# 15   2292741   110844    prior            16          0                 15
# 16   2762741    56669    prior             7          4                 12
# 17   2999975    12794    prior             2          0                 13
# 18   3336747   121770    prior            23          0                 16
# 19     85858    38333    prior            15          1                 10
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     30.0         148                 26          0
# 1                      7.0         148                 15          1
# 2                      NaN         148                 10          0
# 3                     13.0         148                 11          0
# 4                      6.0         148                 17          0
# 5                      9.0         148                  3          1
# 6                      NaN         148                 27          0
# 7                      7.0         148                 31          1
# 8                     20.0         148                  6          1
# 9                      8.0         148                 11          1
# 10                     7.0         148                  8          1
# 11                    30.0         148                 15          1
# 12                     3.0         148                 23          1
# 13                     6.0         148                 18          1
# 14                     7.0         148                  4          1
# 15                     3.0         148                  6          1
# 16                     9.0         148                  9          0
# 17                    30.0         148                  8          0
# 18                     4.0         148                  4          1
# 19                     7.0         148                 20          1
#
#    product_name  aisle_id         aisle  department_id department
# 0    Nectarines        24  fresh fruits              4    produce
# 1    Nectarines        24  fresh fruits              4    produce
# 2    Nectarines        24  fresh fruits              4    produce
# 3    Nectarines        24  fresh fruits              4    produce
# 4    Nectarines        24  fresh fruits              4    produce
# 5    Nectarines        24  fresh fruits              4    produce
# 6    Nectarines        24  fresh fruits              4    produce
# 7    Nectarines        24  fresh fruits              4    produce
# 8    Nectarines        24  fresh fruits              4    produce
# 9    Nectarines        24  fresh fruits              4    produce
# 10   Nectarines        24  fresh fruits              4    produce
# 11   Nectarines        24  fresh fruits              4    produce
# 12   Nectarines        24  fresh fruits              4    produce
# 13   Nectarines        24  fresh fruits              4    produce
# 14   Nectarines        24  fresh fruits              4    produce
# 15   Nectarines        24  fresh fruits              4    produce
# 16   Nectarines        24  fresh fruits              4    produce
# 17   Nectarines        24  fresh fruits              4    produce
# 18   Nectarines        24  fresh fruits              4    produce
# 19   Nectarines        24  fresh fruits              4    produce

# %% [markdown]
# # Check missing data

# %%
orders_all_df
# Out:
# DataFrame[order_id: int, user_id: int, eval_set: string, order_number: int, order_dow: int, order_hour_of_day: int, days_since_prior_order: double, product_id: int, add_to_cart_order: int, reordered: int, product_name: string, aisle_id: int, aisle: string, department_id: int, department: string]

# %%
# ckeck if null and NaN values are present in our DF
from pyspark.sql.functions import isnan, when, count, col

orders_all_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) for c in orders_all_df.columns]).toPandas()
# Out:
#    order_id  user_id  eval_set  order_number  order_dow  order_hour_of_day  \
# 0         0        0         0             0          0                  0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                 2078068           0                  0          0
#
#    product_name  aisle_id  aisle  department_id  department
# 0             0         0      0              0           0

# %%
orders_all_df.count()
# Out:
# 33819106

# %%
orders_all_df.printSchema()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- user_id: integer (nullable = true)
#  |-- eval_set: string (nullable = true)
#  |-- order_number: integer (nullable = true)
#  |-- order_dow: integer (nullable = true)
#  |-- order_hour_of_day: integer (nullable = true)
#  |-- days_since_prior_order: double (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- add_to_cart_order: integer (nullable = true)
#  |-- reordered: integer (nullable = true)
#  |-- product_name: string (nullable = true)
#  |-- aisle_id: integer (nullable = true)
#  |-- aisle: string (nullable = true)
#  |-- department_id: integer (nullable = true)
#  |-- department: string (nullable = true)

# %% [markdown]
# # List the most ordered products (top 10)

# %% [markdown]
# ### Using spark.sql querries

# %%
querry1 = """
Select
  product_id,
  product_name,
  SUM(add_to_cart_order)
FROM
  Orders_all 
GROUP BY
  product_id,
  product_name 
ORDER BY
  SUM(add_to_cart_order) DESC
"""
most_ordered_df = spark.sql(querry1)
#most_ordered_df.createOrReplaceTempView('Most_ordered')

# %%
start_time = time.time()

most_ordered_df.show(10)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----------+--------------------+----------------------+
# |product_id|        product_name|sum(add_to_cart_order)|
# +----------+--------------------+----------------------+
# |     24852|              Banana|               2405664|
# |     13176|Bag of Organic Ba...|               2007396|
# |     21137|Organic Strawberries|               2005999|
# |     21903|Organic Baby Spinach|               1870623|
# |     47209|Organic Hass Avocado|               1497887|
# |     47626|         Large Lemon|               1279007|
# |     26209|               Limes|               1261016|
# |     47766|     Organic Avocado|               1187054|
# |     16797|        Strawberries|               1065577|
# |     27966| Organic Raspberries|               1031044|
# +----------+--------------------+----------------------+
# only showing top 10 rows
#
# --- 32.8523211479187 seconds ---

# %% [markdown]
# ### Using dataframe joins

# %%
from pyspark.sql.functions import sum
start_time = time.time()

orders_all_df.select("product_id", "product_name","add_to_cart_order").groupBy("product_id", "product_name").agg(sum("add_to_cart_order")).orderBy(sum("add_to_cart_order"),ascending=False).show(10)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----------+--------------------+----------------------+
# |product_id|        product_name|sum(add_to_cart_order)|
# +----------+--------------------+----------------------+
# |     24852|              Banana|               2405664|
# |     13176|Bag of Organic Ba...|               2007396|
# |     21137|Organic Strawberries|               2005999|
# |     21903|Organic Baby Spinach|               1870623|
# |     47209|Organic Hass Avocado|               1497887|
# |     47626|         Large Lemon|               1279007|
# |     26209|               Limes|               1261016|
# |     47766|     Organic Avocado|               1187054|
# |     16797|        Strawberries|               1065577|
# |     27966| Organic Raspberries|               1031044|
# +----------+--------------------+----------------------+
# only showing top 10 rows
#
# --- 32.087281942367554 seconds ---

# %% [markdown]
# # Do people usually reorder the same previously ordered products?

# %%
querry5 ="""
Select t1.user_id, t1.count as no_of_reordered_product_ids, t2.count as no_of_new_product_ids, t1.count/(t1.count+t2.count) as percent_reordered
FROM 
    (
    Select 
      user_id,
      COUNT(product_id) as count
    FROM
      Orders_all
    WHERE
      reordered = 1
    GROUP BY
      user_id
    ) t1
    JOIN
    (
    Select 
      user_id,
      COUNT(product_id) as count
    FROM
      Orders_all
    WHERE
      reordered = 0
    GROUP BY
      user_id
    ) t2
    ON t1.user_id=t2.user_id
ORDER BY 
 percent_reordered DESC
"""
reordered5_df = spark.sql(querry5)

# %%
reordered5_df.limit(40).show(40)
# Out:
# +-------+---------------------------+---------------------+------------------+
# |user_id|no_of_reordered_product_ids|no_of_new_product_ids| percent_reordered|
# +-------+---------------------------+---------------------+------------------+
# |  99753|                        191|                    2|0.9896373056994818|
# |  82414|                        425|                    8|0.9815242494226328|
# | 107528|                        104|                    2|0.9811320754716981|
# |  17997|                        426|                    9|0.9793103448275862|
# | 170174|                         47|                    1|0.9791666666666666|
# |   3269|                        272|                    6|0.9784172661870504|
# |   5588|                       2178|                   50|0.9775583482944344|
# |  91160|                        207|                    5|0.9764150943396226|
# | 184517|                        205|                    5|0.9761904761904762|
# |  26489|                        186|                    5|0.9738219895287958|
# |  37075|                         36|                    1| 0.972972972972973|
# | 169980|                        177|                    5|0.9725274725274725|
# | 172902|                        282|                    8|0.9724137931034482|
# | 198506|                         93|                    3|           0.96875|
# | 165398|                         60|                    2| 0.967741935483871|
# |  45671|                         58|                    2|0.9666666666666667|
# | 110225|                         58|                    2|0.9666666666666667|
# | 140753|                        426|                   15|0.9659863945578231|
# |  75124|                       1584|                   56|0.9658536585365853|
# | 103593|                       1383|                   49| 0.965782122905028|
# | 100935|                        169|                    6|0.9657142857142857|
# | 160241|                         55|                    2|0.9649122807017544|
# |  84627|                         55|                    2|0.9649122807017544|
# |  86344|                        191|                    7|0.9646464646464646|
# |  74656|                         81|                    3|0.9642857142857143|
# |  41211|                        270|                   10|0.9642857142857143|
# | 154977|                        349|                   13|0.9640883977900553|
# |  88429|                         80|                    3| 0.963855421686747|
# |  39176|                         79|                    3|0.9634146341463414|
# | 167391|                         26|                    1|0.9629629629629629|
# | 203143|                         52|                    2|0.9629629629629629|
# | 145481|                        307|                   12|0.9623824451410659|
# |  65180|                        227|                    9| 0.961864406779661|
# | 106510|                         50|                    2|0.9615384615384616|
# | 106143|                         25|                    1|0.9615384615384616|
# | 166786|                       2065|                   83|0.9613594040968343|
# |  81678|                        645|                   26|0.9612518628912071|
# | 100698|                       1226|                   50|0.9608150470219435|
# |  66087|                         72|                    3|              0.96|
# | 104684|                         24|                    1|              0.96|
# +-------+---------------------------+---------------------+------------------+

# %%
from pyspark.sql.functions import *
result = reordered5_df.agg(avg('no_of_reordered_product_ids'), avg('no_of_new_product_ids'))
result.show()
# Out:
# +--------------------------------+--------------------------+
# |avg(no_of_reordered_product_ids)|avg(no_of_new_product_ids)|
# +--------------------------------+--------------------------+
# |                97.6724471266562|         67.70212276502748|
# +--------------------------------+--------------------------+

# %% [markdown]
# Since avg(no_of_reordered_product_ids) is greater than avg(no_of_new_product_ids), we conclude that the answer is YES: people are 30% more likely to reorder same items than to buy something new.

# %% [markdown]
# ### Alternative approach

# %%
querry3 = """
Select
  t1.product_id,
  t1.product_name,
  t1.s1 / (t2.s2 + t1.s1) AS percent_units_reordered,
  t1.s1 + t2.s2 as units_sold,
  CASE
    WHEN
      t1.s1 / (t2.s2 + t1.s1) >= 0.75 
    THEN
      "YES" 
    WHEN
      t1.s1 / (t2.s2 + t1.s1) < 0.75 
      AND t1.s1 / (t2.s2 + t1.s1) >= 0.5 
    THEN
      "MAYBE" 
    WHEN
      t1.s1 / (t2.s2 + t1.s1) < 0.5 
      AND t1.s1 / (t2.s2 + t1.s1) >= 0.25 
    THEN
      "NOT REALLY" 
    ELSE
      "NO" 
  END
  AS ReorderedText 
FROM
  (
    Select
      product_id,
      product_name,
      SUM(add_to_cart_order) as s1 
    FROM
      Orders_all 
    WHERE
      reordered = 1 
    GROUP BY
      product_id,
      product_name 
  )
  t1 
  FULL OUTER JOIN
    (
      Select
        product_id,
        product_name,
        SUM(add_to_cart_order) as s2 
      FROM
        Orders_all 
      WHERE
        reordered = 0 
      GROUP BY
        product_id,
        product_name 
    )
    t2 
    ON t1.product_id = t2.product_id 
ORDER BY
  percent_units_reordered DESC
"""

reordered1_df = spark.sql(querry3)

# %%
from pyspark.sql.window import Window
df = reordered1_df
window = Window.partitionBy(
    df['ReorderedText']
).orderBy(
    df['percent_units_reordered'].desc()
)

df.select('*', rank().over(window).alias('rank')).filter(col('rank') <= 10).orderBy(
    df['percent_units_reordered'].desc()
).limit(40).toPandas()
# Out:
#     product_id                                       product_name  \
# 0         9889  Dietary Supplement Tablets for Normal Sleep Pa...
# 1        43553                                Orange Energy Shots
# 2        39992                          Energy Shot, Grape Flavor
# 3        14609                          Soy Powder Infant Formula
# 4          802                          Organic Super Berry Juice
# 5        35910                                             Porter
# 6        11082                                  Simtra Triple IPA
# 7        44015                            Classic Citrus Kombucha
# 8        44951          California Ripe Pitted Extra Large Olives
# 9        22096                         California French Dressing
# 10       33572                   Lactose Free 2% Reduced Fat Milk
# 11       24243                   Organic Diabetic Lifestyle Bread
# 12       43845                                    Diet Pepsi Soda
# 13       42309                           Nonfat Vanilla Bio Kefir
# 14       34121                                Organic Roots Juice
# 15       13483                                       Allure Drink
# 16         895       YoKids Squeeze Organic Blueberry Blue Yogurt
# 17        2090                                         Milk, Goat
# 18       22765                  Organic Sliced Fremont Sour White
# 19       30144                                Crystals Cat Litter
# 20       12630                        Pineapple Orange 100% Juice
# 21       27019  Thins Light & Tasty Snack Crackers Lightly Salted
# 22       25025                                    Rye Style Bread
# 23       14191                                Premium Beef Franks
# 24       26635                             Medium Tomatillo Salsa
# 25       10078  Soft Baked Oats and Chocolate Breakfast Biscui...
# 26       13350                        Vine Ripened Golden Berries
# 27        1467                         Mozzarella Ciliegine Fresh
# 28       11110       Dark Chocolate Mocha Almond Fruit & Nut Bars
# 29       30592                                Coconut Oil Popcorn
# 30        4475                              Reclosable Snack Bags
# 31        3099                Fresh Mint Toothpaste With Flouride
# 32       13173                             Beef Ramen Noodle Soup
# 33       31268                                      Sandwich Bags
# 34        7883                                 Jumbo Cotton Balls
# 35       46533                         Organic Toasted Sushi Nori
# 36       17035                      Heart Healthy Minestrone Soup
# 37       12515                                             Lychee
# 38       10744      Chicken Noodle R&W Condensed Soup Family Size
# 39       31420                                      Cole Slaw Kit
#
#     percent_units_reordered  units_sold ReorderedText  rank
# 0                  0.956522          46           YES     1
# 1                  0.956522          46           YES     1
# 2                  0.949153         118           YES     3
# 3                  0.943396          53           YES     4
# 4                  0.936620         426           YES     5
# 5                  0.932039         206           YES     6
# 6                  0.931751         674           YES     7
# 7                  0.926829         123           YES     8
# 8                  0.923077          39           YES     9
# 9                  0.922222          90           YES    10
# 10                 0.749981       39529         MAYBE     1
# 11                 0.749779        1131         MAYBE     2
# 12                 0.749562        1713         MAYBE     3
# 13                 0.749505        5050         MAYBE     4
# 14                 0.749393        1648         MAYBE     5
# 15                 0.748936         235         MAYBE     6
# 16                 0.748804       27584         MAYBE     7
# 17                 0.748652         927         MAYBE     8
# 18                 0.748571        1225         MAYBE     9
# 19                 0.747729        1431         MAYBE    10
# 20                 0.499928        6969    NOT REALLY     1
# 21                 0.499912        5711    NOT REALLY     2
# 22                 0.499867        3753    NOT REALLY     3
# 23                 0.499865        3697    NOT REALLY     4
# 24                 0.499841        3145    NOT REALLY     5
# 25                 0.499838        3083    NOT REALLY     6
# 26                 0.499796        2449    NOT REALLY     7
# 27                 0.499769        8656    NOT REALLY     8
# 28                 0.499748        3966    NOT REALLY     9
# 29                 0.499708        5131    NOT REALLY    10
# 30                 0.249816        1361            NO     1
# 31                 0.249778        1125            NO     2
# 32                 0.249741        1934            NO     3
# 33                 0.249717       39697            NO     4
# 34                 0.249706        4253            NO     5
# 35                 0.249691        1618            NO     6
# 36                 0.249663         741            NO     7
# 37                 0.249658        2191            NO     8
# 38                 0.249641         697            NO     9
# 39                 0.249639        1386            NO    10

# %%
from pyspark.sql.window import Window
df = reordered1_df
window = Window.partitionBy(
    df['ReorderedText']
).orderBy(
    df['units_sold'].desc()
)

df.select('*', rank().over(window).alias('rank')).filter(col('rank') <= 10).orderBy(
    df['units_sold'].desc()
).limit(40).toPandas()
# Out:
#     product_id                                 product_name  \
# 0        24852                                       Banana
# 1        13176                       Bag of Organic Bananas
# 2        21137                         Organic Strawberries
# 3        21903                         Organic Baby Spinach
# 4        47209                         Organic Hass Avocado
# 5        47626                                  Large Lemon
# 6        26209                                        Limes
# 7        47766                              Organic Avocado
# 8        16797                                 Strawberries
# 9        27966                          Organic Raspberries
# 10       22935                         Organic Yellow Onion
# 11       24964                               Organic Garlic
# 12       45007                             Organic Zucchini
# 13       39275                          Organic Blueberries
# 14       40706                       Organic Grape Tomatoes
# 15       27845                           Organic Whole Milk
# 16       31506                       Extra Virgin Olive Oil
# 17        5785                  Organic Reduced Fat 2% Milk
# 18        5025                                 Green Onions
# 19       31553                            Fresh Ginger Root
# 20         890                       Organic Diced Tomatoes
# 21       19048                     Organic Butternut Squash
# 22       30233  Organic Large Brown Grade AA Cage Free Eggs
# 23       47734                        Organic Green Cabbage
# 24       39812                                Organic Thyme
# 25        7021                         Organic Tomato Paste
# 26       44987                         Heavy Whipping Cream
# 27       14947                         Pure Sparkling Water
# 28       38689                     Organic Reduced Fat Milk
# 29       45535             Organic Low Sodium Chicken Broth
# 30       44628                        Organic Dijon Mustard
# 31       31066                                Aluminum Foil
# 32        7500                      Organic Vanilla Extract
# 33        4461   Organic Raw Unfiltered Apple Cider Vinegar
# 34       23405                             Pure Baking Soda
# 35       14332                       Organic Yellow Mustard
# 36        9327                                Garlic Powder
# 37        7746                                      Oregano
# 38       19468                       Classic Yellow Mustard
# 39       45002           Organic Balsamic Vinegar Of Modena
#
#     percent_units_reordered  units_sold ReorderedText  rank
# 0                  0.814670     2405664           YES     1
# 1                  0.798724     2007396           YES     2
# 2                  0.764337     2005999           YES     3
# 3                  0.757061     1870623           YES     4
# 4                  0.773151     1497887           YES     5
# 5                  0.669930     1279007         MAYBE     1
# 6                  0.659409     1261016         MAYBE     2
# 7                  0.729510     1187054         MAYBE     3
# 8                  0.660797     1065577         MAYBE     4
# 9                  0.723778     1031044         MAYBE     5
# 10                 0.682857     1004141         MAYBE     6
# 11                 0.669041     1001654         MAYBE     7
# 12                 0.661396      986367         MAYBE     8
# 13                 0.602388      862073         MAYBE     9
# 14                 0.637780      834206         MAYBE    10
# 15                 0.791925      777566           YES     6
# 16                 0.475422      472887    NOT REALLY     1
# 17                 0.770002      283563           YES     7
# 18                 0.490641      244629    NOT REALLY     2
# 19                 0.466578      226674    NOT REALLY     3
# 20                 0.472153      222324    NOT REALLY     4
# 21                 0.445285      207364    NOT REALLY     5
# 22                 0.752028      206902           YES     8
# 23                 0.495004      199853    NOT REALLY     6
# 24                 0.402711      194569    NOT REALLY     7
# 25                 0.419023      182954    NOT REALLY     8
# 26                 0.465712      177217    NOT REALLY     9
# 27                 0.765747      174683           YES     9
# 28                 0.812445      174104           YES    10
# 29                 0.470247      171212    NOT REALLY    10
# 30                 0.243246      122230            NO     1
# 31                 0.219809      106752            NO     2
# 32                 0.231835       95555            NO     3
# 33                 0.243430       81588            NO     4
# 34                 0.228737       75930            NO     5
# 35                 0.230227       68767            NO     6
# 36                 0.145585       65405            NO     7
# 37                 0.177553       59554            NO     8
# 38                 0.218502       55844            NO     9
# 39                 0.232330       50919            NO    10

# %% [markdown]
# # List most reordered products

# %% [markdown]
# This approach takes into consideration number of items added to cart_order as well as number of orders.

# %%
reordered1_df.limit(30).show(30)
# Out:
# +----------+--------------------+-----------------------+----------+-------------+
# |product_id|        product_name|percent_units_reordered|units_sold|ReorderedText|
# +----------+--------------------+-----------------------+----------+-------------+
# |      9889|Dietary Supplemen...|     0.9565217391304348|        46|          YES|
# |     43553| Orange Energy Shots|     0.9565217391304348|        46|          YES|
# |     39992|Energy Shot, Grap...|     0.9491525423728814|       118|          YES|
# |     14609|Soy Powder Infant...|     0.9433962264150944|        53|          YES|
# |       802|Organic Super Ber...|     0.9366197183098591|       426|          YES|
# |     35910|              Porter|     0.9320388349514563|       206|          YES|
# |     11082|   Simtra Triple IPA|     0.9317507418397626|       674|          YES|
# |     44015|Classic Citrus Ko...|      0.926829268292683|       123|          YES|
# |     44951|California Ripe P...|     0.9230769230769231|        39|          YES|
# |     22096|California French...|     0.9222222222222223|        90|          YES|
# |     42687|  Light 50 Cranberry|     0.9173228346456693|       254|          YES|
# |     38529|Very Rare Blended...|     0.9117647058823529|       102|          YES|
# |       818|    Micro Craft Beer|     0.9046052631578947|       304|          YES|
# |     44903|Celluvisc Lubrica...|     0.9041095890410958|       219|          YES|
# |     40170|        Sheep Butter|                    0.9|       210|          YES|
# |     26093|Soy Crisps Lightl...|     0.8983739837398373|       246|          YES|
# |      8627|        Thyme Hummos|     0.8961267605633803|      1704|          YES|
# |      6433| Raw Veggie Wrappers|     0.8918918918918919|       185|          YES|
# |      2139|Ruination Double ...|     0.8909853249475891|       477|          YES|
# |     10046|Rawhide Chew, Med...|     0.8896103896103896|       154|          YES|
# |      2628|Traditional Origi...|     0.8883089770354906|       958|          YES|
# |     10486|       Nut Brown Ale|     0.8876404494382022|       178|          YES|
# |     43058|Maximum Absorbenc...|     0.8827586206896552|       435|          YES|
# |     38438| Almond Orgeat Syrup|     0.8791946308724832|       149|          YES|
# |     14725|      Obsidian Stout|     0.8783068783068783|       189|          YES|
# |      3380|Premium Dog Food ...|     0.8783068783068783|       189|          YES|
# |      4458|Hot & Fit Mayan B...|     0.8761904761904762|       105|          YES|
# |     24280|Natural Blueberri...|     0.8755020080321285|       249|          YES|
# |     26740|Sparklers Tangeri...|                  0.875|       240|          YES|
# |      5868|Russian River Val...|     0.8714285714285714|        70|          YES|
# +----------+--------------------+-----------------------+----------+-------------+

# %% [markdown]
# ### Alternative approach

# %% [markdown]
# This approach based solely on number of orders and does not consider number of items in cart_order.

# %%
from pyspark.sql.functions import *
orders_all_df.groupBy("product_name").agg(
    avg("reordered").alias("percent_reorders"), 
    count("reordered").alias('no_of_orders'),
    sum("add_to_cart_order").alias("untis_sold"),  
    (sum("add_to_cart_order")/countDistinct("order_id")).alias('units_per_order')
).sort(
    col("percent_reorders").desc()
).limit(20).toPandas()
# Out:
#                                 product_name  percent_reorders  no_of_orders  \
# 0                        Raw Veggie Wrappers          0.942029            69
# 1   Serenity Ultimate Extrema Overnight Pads          0.933333            90
# 2                        Orange Energy Shots          0.923077            13
# 3                         Chocolate Love Bar          0.921569           102
# 4                  Soy Powder Infant Formula          0.914286            35
# 5           Simply Sleep Nighttime Sleep Aid          0.911111            45
# 6                  Energy Shot, Grape Flavor          0.909091            22
# 7    Russian River Valley Reserve Pinot Noir          0.900000            30
# 8                         Bars Peanut Butter          0.898551            69
# 9                  Soy Crisps Lightly Salted          0.895522            67
# 10                        High Gravity Lager          0.894737            38
# 11                           Maca Buttercups          0.894231           104
# 12                       Almond Orgeat Syrup          0.892857            28
# 13                     Benchbreak Chardonnay          0.891892           111
# 14                  Organic Blueberry B Mega          0.888889            99
# 15                            Sparking Water          0.887097            62
# 16          Very Rare Blended  Scotch Whisky          0.880952            42
# 17                      Amazake Almond Shake          0.880000            25
# 18               Steamfresh Garlic Parm Peas          0.875000            32
# 19                                 Pure Zero          0.870968            31
#
#     untis_sold  units_per_order
# 0          185         2.681159
# 1          429         4.766667
# 2           46         3.538462
# 3          375         3.676471
# 4           53         1.514286
# 5          144         3.200000
# 6          118         5.363636
# 7           70         2.333333
# 8          426         6.173913
# 9          246         3.671642
# 10          76         2.000000
# 11         484         4.653846
# 12         149         5.321429
# 13         289         2.603604
# 14         534         5.393939
# 15         240         3.870968
# 16         102         2.428571
# 17         126         5.040000
# 18         284         8.875000
# 19          91         2.935484

# %% [markdown]
# # Most important department and aisle (by number of products)

# %%
# 2: products + aisles + departments
prod_isles_dep_df = df_departments.join(df_products, "department_id").join(df_aisles, "aisle_id")

# %%
prod_isles_dep_df.groupBy("department").count().sort(col("count").desc()).show(10,False)
prod_isles_dep_df.groupBy("aisle").count().sort(col("count").desc()).show(10,False)
# Out:
# +---------------+-----+
# |department     |count|
# +---------------+-----+
# |personal care  |6563 |
# |snacks         |6264 |
# |pantry         |5371 |
# |beverages      |4365 |
# |frozen         |4007 |
# |dairy eggs     |3449 |
# |household      |3085 |
# |canned goods   |2092 |
# |dry goods pasta|1858 |
# |produce        |1684 |
# +---------------+-----+
# only showing top 10 rows
#
# +--------------------+-----+
# |aisle               |count|
# +--------------------+-----+
# |missing             |1258 |
# |candy chocolate     |1246 |
# |ice cream ice       |1091 |
# |vitamins supplements|1038 |
# |yogurt              |1026 |
# |chips pretzels      |989  |
# |tea                 |894  |
# |packaged cheese     |891  |
# |frozen meals        |880  |
# |cookies cakes       |874  |
# +--------------------+-----+
# only showing top 10 rows

# %% [markdown]
# # Get the Top 10 departments

# %%
orders_all_df.groupBy("department").agg(sum("reordered").alias("no_of_orders")).sort(col("no_of_orders").desc()).show(10)
# Out:
# +------------+------------+
# |  department|no_of_orders|
# +------------+------------+
# |     produce|     6432596|
# |  dairy eggs|     3773723|
# |   beverages|     1832952|
# |      snacks|     1727075|
# |      frozen|     1268058|
# |      bakery|      769880|
# |      pantry|      679799|
# |        deli|      666231|
# |canned goods|      511317|
# |meat seafood|      420349|
# +------------+------------+
# only showing top 10 rows

# %% [markdown]
# # List top 10 products ordered in the morning (6 AM to 11 AM)

# %%
orders_all_df.where(
    (orders_all_df["order_hour_of_day"]>6) & (orders_all_df["order_hour_of_day"]<11)
).groupBy("product_name").agg(
    sum("reordered").alias("no_of_orders"),sum("add_to_cart_order").alias("no_of_units")
).sort(col("no_of_units").desc()).show(10)
# Out:
# +--------------------+------------+-----------+
# |        product_name|no_of_orders|no_of_units|
# +--------------------+------------+-----------+
# |              Banana|      107870|     605101|
# |Organic Strawberries|       53909|     503409|
# |Bag of Organic Ba...|       84433|     501032|
# |Organic Baby Spinach|       47174|     457051|
# |Organic Hass Avocado|       42877|     367110|
# |         Large Lemon|       27373|     313270|
# |               Limes|       23580|     301298|
# |     Organic Avocado|       33308|     281429|
# |        Strawberries|       27875|     274751|
# | Organic Raspberries|       29273|     268852|
# +--------------------+------------+-----------+
# only showing top 10 rows
